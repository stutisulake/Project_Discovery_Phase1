# %% [markdown]
# ## Work Summary
# - I refined my project using both primary and secondary research to move from ideation to execution.
# - I revised my problem statement to be precise, quantifiable, and user-centered while concentrating on a particular, hyper-local issue, using the “5 Whys” method to uncover underlying causes.
# - I mapped key stakeholders—including users, local authorities, and service providers—to understand their needs, expectations, and potential conflicts.
# - I began visualizing solutions through low-fidelity wireframes and user journey mapping, which helped identify real-world challenges and develop more feasible solutions.
#
# ## Learnings / Outcomes
# - The "Everything" Trap: Attempting to tackle multiple issues and SDGs at once reduced focus. I resolved this by focusing on a single core problem and eliminating unnecessary elements.
# - Local Data Scarcity: Limited access to city-specific data made validation difficult. I overcame this by using proxy data from comparable cities and supplementing it with primary research.
# - Uncertain Solution Direction: Translating the problem into a practical solution was initially challenging. I addressed this by creating simple wireframes and user journey maps.
# - User Adoption Risk: It is unclear if users will consistently segregate waste daily. This will need validation through testing and feedback in later phases.
#
# ## Blockers / Risks
# - The "Everything" Trap: Trying to solve multiple issues reduced focus. I mitigated this by eliminating extraneous features and concentrating on one main problem.
# - Local Data Scarcity: Limited access to city-level data made validation challenging. I addressed this by using proxy data and supplementing it with primary research.
#
# ## Skills Used
# - Problem Scoping & Root Cause Analysis: Applying the “5 Whys” and refining the core problem.
# - User-Centered Design: Mapping stakeholders and user journeys to focus on real needs.
# - Research & Data Analysis: Synthesizing primary surveys and secondary sources to validate assumptions.
# - Solution Visualization: Creating low-fidelity wireframes for actionable insights.
# - Strategic Planning: Building a project roadmap to guide execution.
# - Technical Tools & Programming: Python, Jupyter Notebook, and ML techniques for analysis.
# - Data Visualization: Using graphs, charts, and plots to explore trends and insights.
#
# ## Conclusion
# - Organize and analyze collected data from surveys and secondary sources.
# - Visualize trends in organic waste generation and user behavior using charts, plots, and dashboards.
# - Apply Python and ML techniques to identify patterns and test small-scale solution prototypes.
# - Document all findings, assumptions, and insights in a structured, reproducible manner.
# - Continuously refine the problem statement and solution approach based on analysis results.
